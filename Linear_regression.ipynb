# %% [markdown]
# <a href="https://colab.research.google.com/github/Godwin-Bright/Machine-Learning/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv("/content/test.csv")
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
x = df.drop("battery_power",axis=1)
x
# Out:
#        id  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0       1     1          1.8         1  14       0           5    0.1
# 1       2     1          0.5         1   4       1          61    0.8
# 2       3     1          2.8         0   1       0          27    0.9
# 3       4     0          0.5         1  18       1          25    0.5
# 4       5     0          1.4         0  11       1          49    0.5
# ..    ...   ...          ...       ...  ..     ...         ...    ...
# 995   996     1          1.9         0   0       1          54    0.5
# 996   997     0          1.8         1   0       0          13    0.9
# 997   998     0          1.4         0   1       1           8    0.5
# 998   999     1          0.5         1   0       0          50    0.4
# 999  1000     1          0.5         0   4       1          35    0.1
#
#      mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
y = df["battery_power"]
y
# Out:
# 0      1043
# 1       841
# 2      1807
# 3      1546
# 4      1434
#        ...
# 995    1700
# 996     609
# 997    1185
# 998    1533
# 999    1270
# Name: battery_power, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
train_X, test_X, train_y, test_y = train_test_split(x,y, train_size=0.5, test_size=0.5, random_state=0)
test_X
# Out:
#       id  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 993  994     1          2.7         1  14       1          56    0.4
# 859  860     1          2.3         1   6       1          51    0.9
# 298  299     1          2.0         1   0       1          16    0.2
# 553  554     0          0.5         0   3       1          20    0.6
# 672  673     1          0.7         0   3       1          22    0.9
# ..   ...   ...          ...       ...  ..     ...         ...    ...
# 647  648     0          2.7         0   4       0          53    0.5
# 190  191     0          1.3         0   5       0          28    0.9
# 361  362     0          0.5         0   0       1          15    0.4
# 664  665     0          1.7         0   6       1          41    0.9
# 375  376     0          1.8         1   6       1          55    0.9
#
#      mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()
ml.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
y_pred = ml.predict( test_X)
print(y_pred )
# Out:
# [1143.80663644 1216.14307691 1156.83576245 1361.84533163 1216.60261727
#  1194.65247771 1333.505998   1218.3896146  1265.35368944 1363.64911415
#  1186.0852691  1425.18706095 1103.11863278 1226.97795822 1290.38336349
#  1209.17553484 1261.54656999 1463.16464242 1223.47737574 1265.32484311
#  1132.06779861 1259.10005032 1248.79478177 1207.07869082 1233.78437441
#  1067.50019498 1354.74191767 1196.77218219 1201.2192993  1178.08935116
#  1276.59637471 1190.48895381 1359.06439473 1339.76716543 1203.72785094
#  1217.75807847 1252.30518766 1306.27022482 1244.7576559  1225.72802874
#  1342.58658391 1176.86911549 1132.11731609 1117.73384991 1255.57377665
#  1228.22592047 1198.7855566  1112.88652038 1214.50978508 1225.93323709
#  1234.01218629 1338.73510143 1261.89971212 1207.60684701 1180.44857511
#  1319.24526213 1278.05256834 1267.88741376 1043.07180183 1062.74727979
#  1104.42487717 1330.66422297 1177.59583736 1128.65271099 1203.30330067
# ...

# %%
from sklearn.metrics import r2_score
r2_score(test_y,y_pred)
# Out:
# -0.017641012182624705

# %%
plt.scatter(test_y,y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title('Actual vs predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs predicted')
